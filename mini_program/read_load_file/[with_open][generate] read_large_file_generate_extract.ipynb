# %% [markdown]
# # simple generate function

# %%
def num_squence(n):
    i=0
    while i<n:
        yield i
        i += 1

# %%
list(num_squence(3))
# Out:
# [0, 1, 2]

# %% [markdown]
# # open file with generate function

# %%
#define read_large_file()
def read_large_file(file_object):
    """A generator function to read a large file lazily."""
    
    #generate loop (keep if data not end)
    while True:
        #read line function
        data = file_object.readline()
        #break (break if data is end)
        if not data:
            break
        #set yield (return)
        yield data

# %%
with open('WDI_csv/WDIData.csv') as file:
    gen_file = read_large_file(file)
    print(next(gen_file))
    print(next(gen_file))
    print(next(gen_file))
# Out:
# ﻿"Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021",
#
# ...

# %% [markdown]
# # dict pivot, with generate, using for loop view lines
# > previous practice, use next to print some of lines
#
# > how about using for loop view all lines, like sql scanning all values

# %%
count_dict = {}

# %%
with open('WDI_csv/WDIData.csv') as file:
    for line in read_large_file(file):
        #extract process
        row = line.split(',')
        first_col = row[0]
        
        #dict process
        if first_col in count_dict.keys():
            count_dict[first_col] += 1
        else:
            count_dict[first_col] = 1

# %%
count_dict
# Out:
# {'"Country Name"': 1,
#  '"Africa Eastern and Southern"': 1442,
#  '"Africa Western and Central"': 1442,
#  '"Arab World"': 1442,
#  '"Caribbean small states"': 1442,
#  '"Central Europe and the Baltics"': 1442,
#  '"Early-demographic dividend"': 1442,
#  '"East Asia & Pacific"': 1442,
#  '"East Asia & Pacific (excluding high income)"': 1442,
#  '"East Asia & Pacific (IDA & IBRD countries)"': 1442,
#  '"Euro area"': 1442,
#  '"Europe & Central Asia"': 1442,
#  '"Europe & Central Asia (excluding high income)"': 1442,
#  '"Europe & Central Asia (IDA & IBRD countries)"': 1442,
#  '"European Union"': 1442,
#  '"Fragile and conflict affected situations"': 1442,
#  '"Heavily indebted poor countries (HIPC)"': 1442,
#  '"High income"': 1442,
#  '"IBRD only"': 1442,
#  '"IDA & IBRD total"': 1442,
#  '"IDA blend"': 1442,
#  '"IDA only"': 1442,
#  '"IDA total"': 1442,
#  '"Late-demographic dividend"': 1442,
#  '"Latin America & Caribbean"': 1442,
# ...
