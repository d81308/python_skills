# %%
import pandas as pd
import numpy as np
from random import randint as rnd

import time
import random
def str_time_prop(start, end, time_format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formatted in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))

def random_date(start, end, prop):
    return str_time_prop(start, end, '%m/%d/%Y %I:%M %p', prop)
    
def scatter_data_creator():
    data = pd.DataFrame(columns=['x','y'])
    for index in range(0,30):
        x_data = index+1
        y_data = rnd(30,60)*index
        data = data.append({'x':x_data,'y':y_data},ignore_index=True)
    return data

scatter_data = scatter_data_creator()

# %%
scatter_data
# Out:
#      x     y
# 0    1     0
# 1    2    40
# 2    3    90
# 3    4   108
# 4    5   152
# 5    6   190
# 6    7   210
# 7    8   301
# 8    9   264
# 9   10   405
# 10  11   380
# 11  12   660
# 12  13   408
# 13  14   611
# 14  15   602
# 15  16   825
# 16  17   944
# 17  18   952
# 18  19  1008
# 19  20  1083
# 20  21   960
# 21  22   693
# 22  23  1144
# 23  24  1357
# 24  25   864
# 25  26  1175
# 26  27   910
# 27  28  1620
# 28  29  1176
# 29  30  1421

# %% [markdown]
# # scatter plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(scatter_data.x,scatter_data.y)
plt.xlabel('constant')
plt.ylabel('scatter_value')
plt.show()

# %%
plt.scatter(scatter_data.x,scatter_data.y,color='g',marker='s',alpha=0.6)
plt.show()
