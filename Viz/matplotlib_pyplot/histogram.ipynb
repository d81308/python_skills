# %% [markdown]
# # data creator

# %%
from scipy.stats import gamma
import seaborn as sns
data_gamma = gamma.rvs(a=5, size=10000)
data_gamma_2 = gamma.rvs(a=20, size=600)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
len(x)
# Out:
# 100

# %%
plt.hist(data_gamma, bins = 20, color='blue', alpha=0.3, density=True)
plt.hist(data_gamma_2, bins = 20, color='orange', alpha=0.3, density=True)
plt.show()
